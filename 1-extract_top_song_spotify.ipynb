# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util
import json
import pandas as pd 
import numpy as np
import utils
pd.set_option('display.max_columns', None)

# %%
#variable entorno
cid ="7b90adf482154140bb2ff823fddff587"
secret = "7b03b5d482a84fd08aa92a9051c8e8e8"

# %% [markdown]
# ### Conexion Spotify

# %%
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=cid, 
                                                                              client_secret=secret, requests_timeout = 100))
print(spotify.requests_timeout)
# Out:
# 5

# %% [markdown]
# #### Lista de Canciones Top Global
# https://charts.spotify.com/charts/view/regional-global-weekly/

# %%
df_top_tracks=pd.DataFrame()

# %%
#Lectura ficheros 2020
import datetime

fecha_ini= datetime.datetime(2020,1,2)

for i in range(53):
    part1=r".\spotify_charts\spotify_chart_2020\regional-global-weekly-"
    part2=".csv"
    fecha_texto = fecha_ini.strftime("%Y-%m-%d")
    fichero = f'{part1}{fecha_texto}{part2}'  
    df_top_tracks_part= pd.read_csv(fichero)
    df_top_tracks=pd.concat([df_top_tracks, df_top_tracks_part], ignore_index=True)
    fecha_ini = fecha_ini + datetime.timedelta(days=7)

# %%
#Lectura ficheros 2021
import datetime

fecha_ini= datetime.datetime(2021,1,7)

for i in range(52):
    part1=r".\spotify_charts\spotify_chart_2021\regional-global-weekly-"
    part2=".csv"
    fecha_texto = fecha_ini.strftime("%Y-%m-%d")
    fichero = f'{part1}{fecha_texto}{part2}'  
    df_top_tracks_part= pd.read_csv(fichero)
    df_top_tracks=pd.concat([df_top_tracks, df_top_tracks_part], ignore_index=True)
    fecha_ini = fecha_ini + datetime.timedelta(days=7)

# %%
#Lectura ficheros 2022
import datetime

fecha_ini= datetime.datetime(2022,1,6)

for i in range(50):
    part1=r".\spotify_charts\spotify_chart_2022\regional-global-weekly-"
    part2=".csv"
    fecha_texto = fecha_ini.strftime("%Y-%m-%d")
    fichero = f'{part1}{fecha_texto}{part2}'  
    df_top_tracks_part= pd.read_csv(fichero)
    df_top_tracks=pd.concat([df_top_tracks, df_top_tracks_part], ignore_index=True)
    fecha_ini = fecha_ini + datetime.timedelta(days=7)

# %%
df_top_tracks.shape
# Out:
# (30998, 9)

# %%
df_top_tracks.drop_duplicates(subset=['uri'], inplace=True)

# %%
df_top_tracks.shape
# Out:
# (2947, 9)

# %%
df_top_tracks.head()
# Out:
#    rank                                   uri          artist_names  \
# 0     1  spotify:track:1rgnBhdG2JDFTbYkYRZAku           Tones And I
# 1     2  spotify:track:696DnlkuDOXcMAnKlTgXXK        Arizona Zervas
# 2     3  spotify:track:7k4t7uLgtOxPwTpFmtJNTY  KAROL G, Nicki Minaj
# 3     4  spotify:track:2b8fOow8UzyDFAE27YhOZM              Maroon 5
# 4     5  spotify:track:4TnjEaWOeW0eKTKIEvJyCa         Trevor Daniel
#
#      track_name                        source  peak_rank  previous_rank  \
# 0  Dance Monkey                 Elektra (NEK)          1              1
# 1       ROXANNE                Arizona Zervas          2              4
# 2          Tusa  TUSA - Karol G & Nicki Minaj          3              6
# 3      Memories           Interscope Records*          2              9
# 4       Falling                         Alamo          5              8
#
#    weeks_on_chart   streams
# 0              24  50183626
# 1              10  33254585
# 2               8  29349573
# 3              15  26067853
# 4               7  25901488

# %%
df_tracks_id = df_top_tracks[['uri']]

# %%
df_tracks_id.columns = ['track_id']

# %%
#Almaceno salida de IDs de Tops tracks

df_tracks_id.to_csv('2000-2022_top_tracks_id.csv', encoding='utf-8' )

# %% [markdown]
# ### Extract Track
#
# Get Spotify catalog information for a single track identified by its unique Spotify ID.
#
# https://developer.spotify.com/documentation/web-api/reference/#/operations/get-track

# %%
def extract_tracks_info(list_tracks):
    df_tracks_info = pd.DataFrame()
    #track = spotify.track("spotify:track:3nqQXoyQOWXiESFLlDF1hG")
    for track in list_tracks:
        track = spotify.track(track)
        df_track = pd.json_normalize(track)
        df_tracks_info = pd.concat([df_tracks_info, df_track], ignore_index=True)
    return df_tracks_info

# %%
df_tracks_info = extract_tracks_info(list_tracks)

# %%
df_tracks_info.shape
# Out:
# (1162, 29)

# %%
df_tracks_info.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\cbaut\Dropbox\kschool\Proyecto\TFM\extract_song_spotify.ipynb Cell 19 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cbaut/Dropbox/kschool/Proyecto/TFM/extract_song_spotify.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> df_tracks_info.head()
#
# NameError: name 'df_tracks_info' is not defined

# %% [markdown]
# ### Extract Artist

# %%
artist =spotify.artist('3Xt3RrJMFv5SZkCfUE8C1J')
artist
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Xt3RrJMFv5SZkCfUE8C1J'},
#  'followers': {'href': None, 'total': 805388},
#  'genres': ['dance pop', 'pop', 'post-teen pop', 'transpop'],
#  'href': 'https://api.spotify.com/v1/artists/3Xt3RrJMFv5SZkCfUE8C1J',
#  'id': '3Xt3RrJMFv5SZkCfUE8C1J',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb4427cfe93e6870af2a81fd41',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab676161000051744427cfe93e6870af2a81fd41',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f1784427cfe93e6870af2a81fd41',
#    'width': 160}],
#  'name': 'Kim Petras',
#  'popularity': 81,
#  'type': 'artist',
#  'uri': 'spotify:artist:3Xt3RrJMFv5SZkCfUE8C1J'}

# %%
spotify.album('0gX9tkL5njRax8ymWcXARi')
# Out:
# {'album_type': 'single',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#    'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#    'id': '2wY79sveU1sp5g7SokKOiI',
#    'name': 'Sam Smith',
#    'type': 'artist',
#    'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Xt3RrJMFv5SZkCfUE8C1J'},
#    'href': 'https://api.spotify.com/v1/artists/3Xt3RrJMFv5SZkCfUE8C1J',
#    'id': '3Xt3RrJMFv5SZkCfUE8C1J',
#    'name': 'Kim Petras',
#    'type': 'artist',
#    'uri': 'spotify:artist:3Xt3RrJMFv5SZkCfUE8C1J'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IQ',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'LY',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TJ',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VE',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'copyrights': [{'text': '© 2022 Universal Music Operations Limited',
#    'type': 'C'},
#   {'text': 'A Capitol Records UK / EMI release; ℗ 2022 Universal Music Operations Limited',
#    'type': 'P'}],
#  'external_ids': {'upc': '00602445856756'},
#  'external_urls': {'spotify': 'https://open.spotify.com/album/0gX9tkL5njRax8ymWcXARi'},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/albums/0gX9tkL5njRax8ymWcXARi',
#  'id': '0gX9tkL5njRax8ymWcXARi',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273a935e4689f15953311772cc4',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02a935e4689f15953311772cc4',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851a935e4689f15953311772cc4',
#    'width': 64}],
#  'label': 'EMI',
#  'name': 'Unholy (feat. Kim Petras)',
#  'popularity': 84,
#  'release_date': '2022-09-22',
#  'release_date_precision': 'day',
#  'total_tracks': 1,
#  'tracks': {'href': 'https://api.spotify.com/v1/albums/0gX9tkL5njRax8ymWcXARi/tracks?offset=0&limit=50',
#   'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#       'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#       'id': '2wY79sveU1sp5g7SokKOiI',
#       'name': 'Sam Smith',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Xt3RrJMFv5SZkCfUE8C1J'},
#       'href': 'https://api.spotify.com/v1/artists/3Xt3RrJMFv5SZkCfUE8C1J',
#       'id': '3Xt3RrJMFv5SZkCfUE8C1J',
#       'name': 'Kim Petras',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Xt3RrJMFv5SZkCfUE8C1J'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 156943,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3nqQXoyQOWXiESFLlDF1hG'},
#     'href': 'https://api.spotify.com/v1/tracks/3nqQXoyQOWXiESFLlDF1hG',
#     'id': '3nqQXoyQOWXiESFLlDF1hG',
#     'is_local': False,
#     'name': 'Unholy (feat. Kim Petras)',
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3nqQXoyQOWXiESFLlDF1hG'}],
#   'limit': 50,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 1},
#  'type': 'album',
#  'uri': 'spotify:album:0gX9tkL5njRax8ymWcXARi'}

# %%
spotify.recommendation_genre_seeds()
# Out:
# {'genres': ['acoustic',
#   'afrobeat',
#   'alt-rock',
#   'alternative',
#   'ambient',
#   'anime',
#   'black-metal',
#   'bluegrass',
#   'blues',
#   'bossanova',
#   'brazil',
#   'breakbeat',
#   'british',
#   'cantopop',
#   'chicago-house',
#   'children',
#   'chill',
#   'classical',
#   'club',
#   'comedy',
#   'country',
#   'dance',
#   'dancehall',
#   'death-metal',
#   'deep-house',
#   'detroit-techno',
#   'disco',
#   'disney',
#   'drum-and-bass',
#   'dub',
#   'dubstep',
#   'edm',
#   'electro',
#   'electronic',
#   'emo',
#   'folk',
#   'forro',
#   'french',
#   'funk',
#   'garage',
#   'german',
#   'gospel',
#   'goth',
#   'grindcore',
#   'groove',
#   'grunge',
#   'guitar',
#   'happy',
#   'hard-rock',
#   'hardcore',
#   'hardstyle',
#   'heavy-metal',
#   'hip-hop',
#   'holidays',
#   'honky-tonk',
#   'house',
#   'idm',
#   'indian',
#   'indie',
#   'indie-pop',
#   'industrial',
#   'iranian',
#   'j-dance',
#   'j-idol',
#   'j-pop',
#   'j-rock',
#   'jazz',
#   'k-pop',
#   'kids',
#   'latin',
#   'latino',
#   'malay',
#   'mandopop',
#   'metal',
#   'metal-misc',
#   'metalcore',
#   'minimal-techno',
#   'movies',
#   'mpb',
#   'new-age',
#   'new-release',
#   'opera',
#   'pagode',
#   'party',
#   'philippines-opm',
#   'piano',
#   'pop',
#   'pop-film',
#   'post-dubstep',
#   'power-pop',
#   'progressive-house',
#   'psych-rock',
#   'punk',
#   'punk-rock',
#   'r-n-b',
#   'rainy-day',
#   'reggae',
#   'reggaeton',
#   'road-trip',
#   'rock',
#   'rock-n-roll',
#   'rockabilly',
#   'romance',
#   'sad',
#   'salsa',
#   'samba',
#   'sertanejo',
#   'show-tunes',
#   'singer-songwriter',
#   'ska',
#   'sleep',
#   'songwriter',
#   'soul',
#   'soundtracks',
#   'spanish',
#   'study',
#   'summer',
#   'swedish',
#   'synth-pop',
#   'tango',
#   'techno',
#   'trance',
#   'trip-hop',
#   'turkish',
#   'work-out',
#   'world-music']}

# %% [markdown]
# ### Extract Track´s Audio Analysis
# Get a low-level audio analysis for a track in the Spotify catalog. The audio analysis describes the track’s structure and musical content, including rhythm, pitch, and timbre.
#
# https://developer.spotify.com/documentation/web-api/reference/#/operations/get-audio-analysis

# %%
def extract_audio_analysis(list_tracks):
    df_audio_analysis = pd.DataFrame()
    #track_analysis =spotify.audio_analysis("spotify:track:3nqQXoyQOWXiESFLlDF1hG")
    for track in list_tracks:
        track_analysis =spotify.audio_analysis(track)
        df_track_analysis = pd.json_normalize(track_analysis)
        df_track_analysis['uri']=track
        df_audio_analysis = pd.concat([df_audio_analysis, df_track_analysis], ignore_index=True)
    return df_audio_analysis

# %%
len(list_tracks)
# Out:
# 1162

# %%
list_tracks.to_csv("tracks.csv")

# %%
#eliminar 5664,spotify:track:4LaGu95Ui2s4vprSQYWUAZ
list_tracks = list_tracks.drop([5664])

# %%
df_tracks_analysis = extract_audio_analysis(list_tracks)

# %%
df_tracks_analysis.shape
# Out:
# (1161, 39)

# %%
df_tracks_analysis.head()
# Out:
#                                                 bars  \
# 0  [{'start': 0.37678, 'duration': 2.16722, 'conf...
# 1  [{'start': 0.23935, 'duration': 2.61977, 'conf...
# 2  [{'start': 1.26362, 'duration': 1.40759, 'conf...
# 3  [{'start': 0.65105, 'duration': 1.67563, 'conf...
# 4  [{'start': 1.29547, 'duration': 1.46587, 'conf...
#
#                                                beats  \
# 0  [{'start': 0.37678, 'duration': 0.53397, 'conf...
# 1  [{'start': 0.23935, 'duration': 0.65329, 'conf...
# 2  [{'start': 0.20422, 'duration': 0.36619, 'conf...
# 3  [{'start': 0.22426, 'duration': 0.42678, 'conf...
# 4  [{'start': 0.56683, 'duration': 0.36369, 'conf...
#
#                                             sections  \
# 0  [{'start': 0.0, 'duration': 16.75491, 'confide...
# 1  [{'start': 0.0, 'duration': 8.13793, 'confiden...
# 2  [{'start': 0.0, 'duration': 11.98776, 'confide...
# 3  [{'start': 0.0, 'duration': 6.4766, 'confidenc...
# 4  [{'start': 0.0, 'duration': 10.08147, 'confide...
#
#                                             segments  \
# 0  [{'start': 0.0, 'duration': 0.3112, 'confidenc...
# 1  [{'start': 0.0, 'duration': 0.21483, 'confiden...
# 2  [{'start': 0.0, 'duration': 0.08857, 'confiden...
# 3  [{'start': 0.0, 'duration': 0.20912, 'confiden...
# 4  [{'start': 0.0, 'duration': 0.54562, 'confiden...
#
#                                               tatums meta.analyzer_version  \
# 0  [{'start': 0.37678, 'duration': 0.26699, 'conf...                 4.0.0
# 1  [{'start': 0.23935, 'duration': 0.32664, 'conf...                 4.0.0
# 2  [{'start': 0.20422, 'duration': 0.1831, 'confi...                 4.0.0
# 3  [{'start': 0.22426, 'duration': 0.21339, 'conf...                 4.0.0
# 4  [{'start': 0.56683, 'duration': 0.18184, 'conf...                 4.0.0
#
#   meta.platform meta.detailed_status  meta.status_code  meta.timestamp  \
# 0         Linux                   OK                 0      1606345705
# 1         Linux                   OK                 0      1595457478
# 2         Linux                   OK                 0      1584947131
# 3         Linux                   OK                 0      1604032973
# 4         Linux                   OK                 0      1601680816
#
#    meta.analysis_time              meta.input_process  track.num_samples  \
# 0             9.37266  libvorbisfile L+R 44100->22050            4522235
# 1            15.98881  libvorbisfile L+R 44100->22050            3098592
# 2            15.17442  libvorbisfile L+R 44100->22050            4410882
# 3             8.78850  libvorbisfile L+R 44100->22050            3799761
# 4            16.84066  libvorbisfile L+R 44100->22050            3945774
#
#    track.duration track.sample_md5  track.offset_seconds  \
# 0       205.09003                                      0
# 1       140.52571                                      0
# 2       200.04000                                      0
# 3       172.32475                                      0
# 4       178.94667                                      0
#
#    track.window_seconds  track.analysis_sample_rate  track.analysis_channels  \
# 0                     0                       22050                        1
# 1                     0                       22050                        1
# 2                     0                       22050                        1
# 3                     0                       22050                        1
# 4                     0                       22050                        1
#
#    track.end_of_fade_in  track.start_of_fade_out  track.loudness  track.tempo  \
# 0               0.31120                191.50658         -10.059      109.928
# 1               0.21483                136.34177          -3.558       90.989
# 2               0.00000                193.09714          -5.934      171.005
# 3               0.20912                162.10431          -4.771      144.015
# 4               0.54562                173.86522          -4.158      163.908
#
#    track.tempo_confidence  track.time_signature  \
# 0                   0.166                     4
# 1                   0.136                     4
# 2                   0.875                     4
# 3                   0.726                     4
# 4                   0.487                     4
#
#    track.time_signature_confidence  track.key  track.key_confidence  \
# 0                            0.972          4                 0.691
# 1                            1.000          7                 0.615
# 2                            1.000          1                 0.000
# 3                            1.000          0                 0.170
# 4                            1.000          1                 0.803
#
#    track.mode  track.mode_confidence  \
# 0           0                  0.519
# 1           0                  0.638
# 2           1                  0.152
# 3           1                  0.344
# 4           0                  0.816
#
#                                     track.codestring  track.code_version  \
# 0  eJxVmokRHDkMA1OZEPQ_-Sd23dC67HPdY2lnZyUKBEFS-5...                3.15
# 1  eJxVmol1KLkRA1OZEHgf-SfmKlD6Wnu9b8XRHOwLQDdVdy...                3.15
# 2  eJxdmgl2ZLkNBK9SR-C-3P9ijkhWSxr3s-eJLH4uIJBIAJ...                3.15
# 3  eJxdmguS5CgMRK_iI5g_3P9i-15SNd3bG7ETDXZh0CeVkj...                3.15
# 4  eJxVmgmSJKkORK-SR2Bf7n-xec_JquqxP7-sISMIEJLL5V...                3.15
#
#                                track.echoprintstring  track.echoprint_version  \
# 0  eJzdvQmyLLuRZLklzMNyMO5_CX0UN4Uv6zfdrlQ9YVZLky...                     4.12
# 1  eJzlnQuS5LgRZK9E_IHj4Hv_I-zzSKlTXaZE2Vipd2ZtZz...                     4.12
# 2  eJzNvQmWLLmNtLsl50wuh-P-l_A-Q5QqpNvPmaf_PHXUPU...                     4.12
# 3  eJztnQuSJDmOZK9k_JPH4ff-R9in8JqM6pw1xuRmp1SPyP...                     4.12
# 4  eJztvQuS5TiuZTsliX8Oh9_5D-GtDeUNZbr1oXeYZ3TdMn...                     4.12
#
#                                    track.synchstring  track.synch_version  \
# 0  eJxNlguW5SAIRLfiEoIf1P1vbOoWvpk5nX6JCUIBBdj7t7...                  1.0
# 1  eJxdWQmW5DoKvIqPICG03f9iQyyq7D-vq7OcthYEQRC4It...                  1.0
# 2  eJxVWAlyxDAI-4qfYMDn_z9WkOS0ne5mG8cHhxAQ9z57i2...                  1.0
# 3  eJxlWAm25CgMuwpHwMZs97_YWJJJ_X7zun46IQS8yjLuff...                  1.0
# 4  eJxlmAuWJSkIRLfiEhLB3_43NsRFq2pmznmdZZqICEGA3f...                  1.0
#
#                                   track.rhythmstring  track.rhythm_version  \
# 0  eJxtmwlyZDkOQ6-SR9C-3P9iQ-BRma6ZiWi3y_ZfJIoLAD...                   1.0
# 1  eJxlWgduJDkM_Eo_QaLy_z92rCCNFwfswvZMB4mhWCyq1h...                   1.0
# 2  eJyVXAmS5Dquu4qPYO3S_S82BEBKclbPxP8Rr7u6MmUtFA...                   1.0
# 3  eJx9eweWIzuM5FV0BHqQ97_YIgyy68_u7HttqqQUDWwgAP...                   1.0
# 4  eJydWwmSLKkOu0odIdnh_hcbS7KBrO6e-fEjXke9ygWMke...                   1.0
#
#                                     uri
# 0  spotify:track:4MzXwWMhyBbmu6hOcLVD49
# 1  spotify:track:3tjFYV6RSFtuktYl3ZtYcq
# 2  spotify:track:0VjIjW4GlUZAMYd2vXMi3b
# 3  spotify:track:35mvY5S1H3J2QZyna3TFe0
# 4  spotify:track:7vrJn5hDSXRmdXoR30KgF1

# %% [markdown]
# ### Extract Track´s Audio Features
#
# Get audio feature information for a single track identified by its unique Spotify ID.
#
# https://developer.spotify.com/documentation/web-api/reference/#/operations/get-audio-features

# %%
def extract_audio_features(list_tracks):
    df_audio_features = pd.DataFrame()
    #track_features=spotify.audio_features("spotify:track:3nqQXoyQOWXiESFLlDF1hG")
    for track in list_tracks:
        track_features =spotify.audio_features(track)
        df_track_features = pd.json_normalize(track_features)
        df_audio_features = pd.concat([df_audio_features, df_track_features], ignore_index=True)
    return df_audio_features

# %%
df_track_features = extract_audio_features(list_tracks)

# %%
df_track_features.shape
# Out:
# (1161, 18)

# %%
df_track_features.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.731   0.573    4   -10.059     0       0.0544       0.40100
# 1         0.700   0.722    7    -3.558     0       0.0369       0.22100
# 2         0.514   0.730    1    -5.934     1       0.0598       0.00146
# 3         0.737   0.802    0    -4.771     1       0.0878       0.46800
# 4         0.863   0.666    1    -4.158     0       0.1520       0.21200
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000052    0.1130    0.145  109.928  audio_features
# 1          0.000000    0.2720    0.756   90.989  audio_features
# 2          0.000095    0.0897    0.334  171.005  audio_features
# 3          0.000000    0.0931    0.682  144.015  audio_features
# 4          0.000493    0.1030    0.838  163.908  audio_features
#
#                        id                                   uri  \
# 0  4MzXwWMhyBbmu6hOcLVD49  spotify:track:4MzXwWMhyBbmu6hOcLVD49
# 1  3tjFYV6RSFtuktYl3ZtYcq  spotify:track:3tjFYV6RSFtuktYl3ZtYcq
# 2  0VjIjW4GlUZAMYd2vXMi3b  spotify:track:0VjIjW4GlUZAMYd2vXMi3b
# 3  35mvY5S1H3J2QZyna3TFe0  spotify:track:35mvY5S1H3J2QZyna3TFe0
# 4  7vrJn5hDSXRmdXoR30KgF1  spotify:track:7vrJn5hDSXRmdXoR30KgF1
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4MzXwWMhyBbm...
# 1  https://api.spotify.com/v1/tracks/3tjFYV6RSFtu...
# 2  https://api.spotify.com/v1/tracks/0VjIjW4GlUZA...
# 3  https://api.spotify.com/v1/tracks/35mvY5S1H3J2...
# 4  https://api.spotify.com/v1/tracks/7vrJn5hDSXRm...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4MzX...       205090
# 1  https://api.spotify.com/v1/audio-analysis/3tjF...       140526
# 2  https://api.spotify.com/v1/audio-analysis/0VjI...       200040
# 3  https://api.spotify.com/v1/audio-analysis/35mv...       172325
# 4  https://api.spotify.com/v1/audio-analysis/7vrJ...       178947
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %% [markdown]
# ### Union DataFrames

# %%
df_top_tracks_all = df_top_tracks.merge(df_tracks_info, how='left', on='uri')

# %%
df_top_tracks_all = df_top_tracks_all.merge(df_track_features, how='left', on='uri')

# %%
df_top_tracks_all = df_top_tracks_all.merge(df_tracks_analysis, how='left', on='uri')

# %%
df_top_tracks_all.shape
# Out:
# (1162, 92)

# %%
#eliminar 5664,spotify:track:4LaGu95Ui2s4vprSQYWUAZ
df_top_tracks_all_ = df_top_tracks_all[~df_top_tracks_all['uri'].isin(["spotify:track:4LaGu95Ui2s4vprSQYWUAZ"])]

# %%
df_top_tracks_all_.shape
# Out:
# (1161, 92)

# %%
df_top_tracks_all_.to_csv("Top_Tracks_2021.csv", sep=";")
