# %%
pip install spotipy
# Out:
# ...
#      |████████████████████████████████| 246 kB 2.3 MB/s eta 0:00:0101
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json
import pandas as pd 
import numpy as np
pd.set_option('display.max_columns', None)

# %%
#variable entorno
cid =""
secret = ""

# %%
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=cid, client_secret=secret, requests_timeout = 100))
print(spotify.requests_timeout)
# Out:
# 5

# %%
spotify.requests_timeout=100
print(spotify)

# %% [markdown]
# ## Extraer lista de canciones por país

# %%
result = spotify.featured_playlists(country="ES", limit=50)

# %%
result
# Out:
# {'message': 'Una ración de música marchando',
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?country=ES&timestamp=2022-07-31T12%3A15%3A17&offset=0&limit=50',
#   'items': [{'collaborative': False,
#     'description': 'Relájate y deja que la música te acompañe.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWV1PBrIG2weG'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWV1PBrIG2weG',
#     'id': '37i9dQZF1DWV1PBrIG2weG',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000393d77c21af8cd01e6715a185',
#       'width': None}],
#     'name': 'Temazos Chill',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
# ...

# %%
playlist_es = pd.DataFrame(result['playlists'])

# %%
len(playlist_es['items'])
# Out:
# 10

# %%
playlist_es['items'][0]
# Out:
# {'collaborative': False,
#  'description': 'Relájate y deja que la música te acompañe.',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWV1PBrIG2weG'},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWV1PBrIG2weG',
#  'id': '37i9dQZF1DWV1PBrIG2weG',
#  'images': [{'height': None,
#    'url': 'https://i.scdn.co/image/ab67706f0000000393d77c21af8cd01e6715a185',
#    'width': None}],
#  'name': 'Temazos Chill',
#  'owner': {'display_name': 'Spotify',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#   'href': 'https://api.spotify.com/v1/users/spotify',
#   'id': 'spotify',
#   'type': 'user',
#   'uri': 'spotify:user:spotify'},
#  'primary_color': None,
#  'public': None,
#  'snapshot_id': 'MTY1ODE3MTQ1MSwwMDAwMDAwMGVkMWMwMjY3MDJhNTA4ZGVmZjQ2NjM5MWVkNzUxZTVl',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWV1PBrIG2weG/tracks',
#   'total': 100},
#  'type': 'playlist',
# ...

# %%
tracks_playlist_es = spotify.playlist_tracks(playlist_id="37i9dQZF1DWVhcOv4ieuap")
tracks_playlist_es =pd.DataFrame(tracks_playlist_es)
data_track_playlist_es=json.dumps(tracks_playlist_es['items'][0])
json_track_playlist = json.loads(data_track_playlist_es)
df_track_playlist_es = json_normalize(json_track_playlist)
df_track_playlist_es
# Out:
#                added_at  is_local primary_color  \
# 0  2022-07-06T08:46:34Z     False          None
#
#    added_by.external_urls.spotify                      added_by.href  \
# 0  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
#
#   added_by.id added_by.type   added_by.uri track.album.album_type  \
# 0                      user  spotify:user:                 single
#
#                                  track.album.artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
#
#                        track.album.available_markets  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
#
#                    track.album.external_urls.spotify  \
# 0  https://open.spotify.com/album/2pqdSWeJVsXAhHF...
#
#                                     track.album.href          track.album.id  \
# 0  https://api.spotify.com/v1/albums/2pqdSWeJVsXA...  2pqdSWeJVsXAhHFuVLzuA8
#
#                                   track.album.images track.album.name  \
# ...

# %%
track_es=spotify.tracks(["3k3NWokhRRkEPhCzPmV8TW"])
df_track_es= pd.DataFrame(track_es['tracks'])
df_track_es.head()
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#    duration_ms  explicit              external_ids  \
# 0       258298     False  {'isrc': 'QM6MZ2214888'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/3k...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/3k3NWokhRRkE...  3k3NWokhRRkEPhCzPmV8TW
#
#    is_local           name  popularity  \
# 0     False  Ojitos Lindos          97
#
#                                          preview_url  track_number   type  \
# ...

# %%
track_analysis_es=spotify.audio_analysis("3k3NWokhRRkEPhCzPmV8TW")
data_track_analysis_es=json.dumps(track_analysis_es)
json_track_analysis = json.loads(data_track_analysis_es)
json_normalize(json_track_analysis)
# Out:
#                                                 bars  \
# 0  [{'start': 3.14584, 'duration': 3.03168, 'conf...
#
#                                                beats  \
# 0  [{'start': 0.812, 'duration': 0.788, 'confiden...
#
#                                             sections  \
# 0  [{'start': 0.0, 'duration': 12.01754, 'confide...
#
#                                             segments  \
# 0  [{'start': 0.0, 'duration': 0.53338, 'confiden...
#
#                                               tatums meta.analyzer_version  \
# 0  [{'start': 0.812, 'duration': 0.394, 'confiden...                 4.0.0
#
#   meta.platform meta.detailed_status  meta.status_code  meta.timestamp  \
# 0         Linux                   OK                 0      1651798487
#
#    meta.analysis_time              meta.input_process  track.num_samples  \
# 0            10.53452  libvorbisfile L+R 44100->22050            5695488
#
#    track.duration track.sample_md5  track.offset_seconds  \
# ...

# %%
from pandas import json_normalize
track_features_es=spotify.audio_features("3k3NWokhRRkEPhCzPmV8TW")
data_track_features_es=json.dumps(track_features_es)
json_track_features_es = json.loads(data_track_features_es)
json_normalize(json_track_features_es)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.647   0.686    3    -5.745     0       0.0413          0.08
#
#    instrumentalness  liveness  valence   tempo            type  \
# 0          0.000001     0.528    0.268  79.928  audio_features
#
#                        id                                   uri  \
# 0  3k3NWokhRRkEPhCzPmV8TW  spotify:track:3k3NWokhRRkEPhCzPmV8TW
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3k3NWokhRRkE...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3k3N...       258299
#
#    time_signature
# 0               4

# %%
df_track_playlist_es["track.album.id"][0]
# Out:
# '2pqdSWeJVsXAhHFuVLzuA8'

# %%
album_es = spotify.album(df_track_playlist_es["track.album.id"][0])
data_album_es=json.dumps(album_es)
json_album_es = json.loads(data_album_es)
df_album_es = json_normalize(json_album_es)
df_album_es.head()
# Out:
#   album_type                                            artists  \
# 0     single  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
#
#                                           copyrights genres  \
# 0  [{'text': '(P) 2022 Erskine Records Limited, u...     []
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/albums/2pqdSWeJVsXA...  2pqdSWeJVsXAhHFuVLzuA8
#
#                                               images     label       name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Columbia  As It Was
#
#    popularity release_date release_date_precision  total_tracks   type  \
# 0          82   2022-03-31                    day             1  album
#
#                                     uri external_ids.upc  \
# 0  spotify:album:2pqdSWeJVsXAhHFuVLzuA8     196589032720
#
# ...

# %%
df_album_es["artists"][0]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6KImCVD70vtIoJWnq6nGn3'},
#   'href': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3',
#   'id': '6KImCVD70vtIoJWnq6nGn3',
#   'name': 'Harry Styles',
#   'type': 'artist',
#   'uri': 'spotify:artist:6KImCVD70vtIoJWnq6nGn3'}]

# %%
artist_es = spotify.artist("6KImCVD70vtIoJWnq6nGn3")
artist_es
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/6KImCVD70vtIoJWnq6nGn3'},
#  'followers': {'href': None, 'total': 22320928},
#  'genres': ['pop'],
#  'href': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3',
#  'id': '6KImCVD70vtIoJWnq6nGn3',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5ebf7db7c8ede90a019c54590bb',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab67616100005174f7db7c8ede90a019c54590bb',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f178f7db7c8ede90a019c54590bb',
#    'width': 160}],
#  'name': 'Harry Styles',
#  'popularity': 92,
#  'type': 'artist',
#  'uri': 'spotify:artist:6KImCVD70vtIoJWnq6nGn3'}
